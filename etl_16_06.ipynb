# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloPaiva7/NOTEBOOKS_COLAB/blob/main/etl_16_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
spreadsheet = gc.open_by_key('1nEu-Hu9um3wa1m4_i1G4Y--drDoB9cbLJydDxhuQbrc')
worksheet = spreadsheet.get_worksheet(7)
df = pd.DataFrame(worksheet.get())
# Code for making the first row as header. Remove if not needed.
df.columns = df.iloc[0]
df = df.drop(0)
df.head()
# Out:
# 0        DATA CONTRATO VALOR                            NOME SALDO DEVEDOR  \
# 1  02/05/2025   229682     1     INDIA NARA LARA DE OLIVEIRA  R$ 60.700,75
# 2  02/05/2025   163275     1         THIAGO DE MELO OLIVEIRA  R$ 22.361,15
# 3  02/05/2025   202155     1              JOSE ROBERTO SILVA  R$ 38.541,00
# 4  02/05/2025   213220     1  EMILIA JOSEFA DA SILVA SILVANO  R$ 52.512,68
# 5  02/05/2025   208593     1          JOSUÉ XAVIER DE CASTRO  R$ 77.095,13
#
# 0      DESCONTO       % PROCESSO CONSULTOR   ESCRITÓRIO  ...               \
# 1   R$ 9.512,41  84,33%      NÃO  HEVERTOW   GUARAPUAVA  ...  PONTUAÇÃO
# 2  R$ 10.114,03  54,77%      NÃO   AUGUSTO     BLUMENAU  ...         36
# 3   R$ 8.009,75  79,22%      NÃO  HEVERTOW   GUARAPUAVA  ...         35
# 4   R$ 9.161,21  82,55%      NÃO    SANDRA     CASCÁVEL  ...         34
# 5  R$ 15.033,66  80,50%      NÃO   VANESSA  PASSO FUNDO  ...         33
#
# 0                                 16/06/2025       None                None  \
# 1  RANKING DIÁRIO  PONTUAÇÃO  RANKING DIÁRIO  PONTUAÇÃO
# 2   ALANA ATAIDES          0   ALANA ATAIDES          0          UBERLÂNDIA
# 3  AMANDA SANTANA          0  AMANDA SANTANA          0  CENTRAL DE RESGATE
# 4     ANA GESSICA          0     ANA GESSICA          0            SALVADOR
# 5       ANA LIDIA          0       ANA LIDIA          0              ITAJAÍ
#
# 0 None                     None       None
# 1       RANKING DOS ESCRITÓRIOS  PONTUAÇÃO
# 2   11            NOVO HAMBURGO         51
# 3   17                 CURITIBA         30
# 4    3                 BLUMENAU         26
# 5   12                    NATAL         24
#
# [5 rows x 64 columns]

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.0.41)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (4.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=c911c4188d2ee5055e5c5a4876dd8596cbb61e2dfac5ba1ee12b31d05244913f
#   Stored in directory: /root/.cache/pip/wheels/68/5d/a5/edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
print(df.columns.tolist())
# Out:
# ['DATA', 'CONTRATO', 'VALOR', 'NOME', 'SALDO DEVEDOR', 'DESCONTO', '%', 'PROCESSO', 'CONSULTOR', 'ESCRITÓRIO', 'UF', 'DIRETOR', 'BANCO', 'RESPONSÁVEL', 'SITUAÇÃO', '', '', 'N° DE QUITADOS DEZEMBRO', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '16/06/2025', None, None, None, None, None]

# %%
# Remover colunas sem nome
df = df.loc[:, df.columns.notna()]

# %%
# Remover colunas com nome vazio ou None
df = df.loc[:, df.columns.notnull() & (df.columns != '')]

# %%
print(df.columns.tolist())
# Out:
# ['DATA', 'CONTRATO', 'VALOR', 'NOME', 'SALDO DEVEDOR', 'DESCONTO', '%', 'PROCESSO', 'CONSULTOR', 'ESCRITÓRIO', 'UF', 'DIRETOR', 'BANCO', 'RESPONSÁVEL', 'SITUAÇÃO', 'N° DE QUITADOS DEZEMBRO', '16/06/2025']

# %%
SELECT *
FROM df
WHERE VALOR > 1000
# Out:
# Empty DataFrame
# Columns: [DATA, CONTRATO, VALOR, NOME, SALDO DEVEDOR, DESCONTO, %, PROCESSO, CONSULTOR, ESCRITÓRIO, UF, DIRETOR, BANCO, RESPONSÁVEL, SITUAÇÃO, N° DE QUITADOS DEZEMBRO, 16/06/2025]
# Index: []

# %%
query = """
SELECT *
FROM df
WHERE DESCONTO > 1000
ORDER BY DESCONTO DESC
"""

resultado = pysqldf(query)
resultado.head()
# Out:
#          DATA CONTRATO VALOR                           NOME SALDO DEVEDOR  \
# 0  14/05/2025   175436     1        JORGE BARBOSA SENA NETO  R$ 35.000,00
# 1  09/05/2025   207574     1    ABIGAIL ALVES LESSING VIANA  R$ 46.969,92
# 2  07/05/2025   195778     1        TATIANA PEREIRA ALMEIDA  R$ 68.753,85
# 3  21/05/2025   231036     1   Maria Lucia Nascimento Alves  R$ 48.888,00
# 4  08/05/2025   216144     1  ELIONICE SANTOS DO NASCIMENTO  R$ 44.608,00
#
#       DESCONTO       % PROCESSO CONSULTOR             ESCRITÓRIO  UF  DIRETOR  \
# 0   R$8.030,65  77,06%      NÃO    KARLLA               TRINDADE  GO  LEANDRO
# 1  R$ 9.990,00  78,73%      SIM   FABIANO          NOVO HAMBURGO  RS  ADRIANO
# 2  R$ 9.973,78  85,49%      NÃO   VANESSA              JOINVILLE  SC  ADRIANO
# 3  R$ 9.936,62  79,67%      SIM  MARILENE  FORTALEZA SÃO GERARDO  CE    JULIO
# 4  R$ 9.936,24  77,73%      NÃO  ANDERSON                VITÓRIA  ES  LEANDRO
#
#            BANCO      RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO 16/06/2025
# 0  BV FINANCEIRA    BRUNO MARIANO  QUITADO                               None
# 1      SANTANDER  JULIANA BATISTA  QUITADO                               None
# 2       BRADESCO   AMANDA SANTANA  QUITADO                               None
# 3  BV FINANCEIRA    GABRIEL ALVES  QUITADO                               None
# 4  BV FINANCEIRA   BRUNA CRISTINA  QUITADO                               None

# %%
query = """
SELECT *
FROM df
ORDER BY `SALDO DEVEDOR` DESC
LIMIT 10
"""

resultado = pysqldf(query)
resultado.head()
# Out:
#          DATA CONTRATO VALOR                    NOME SALDO DEVEDOR  \
# 0  08/05/2025   225637     1         GILMAR OLKOWSKI  R$ 97.954,08
# 1  21/05/2025   211743     1    Moises Jose da Silva  R$ 97.585,44
# 2  15/05/2025   214433     1    DAULBER PILAR PIVOTO  R$ 96.282,00
# 3  06/05/2025   191136     1        JOAO MAIA JUNIOR  R$ 95.813,55
# 4  16/05/2025   233053     1  UESLEY PIRES DE AMORIM  R$ 92.429,10
#
#        DESCONTO       % PROCESSO CONSULTOR     ESCRITÓRIO  UF  DIRETOR  \
# 0  R$ 47.650,00  51,35%      SIM    SANDRA       CASCÁVEL  PR    JULIO
# 1  R$ 16.226,40  83,37%      NÃO  MICHELLE     UBERLÂNDIA  MG    JULIO
# 2  R$ 23.123,79  75,98%      NÃO    MATEUS  CAXIAS DO SUL  RS  ADRIANO
# 3  R$ 20.000,00  79,13%      NÃO   DOUGLAS       CURITIBA  PR    JULIO
# 4  R$ 24.865,76  73,10%      SIM     ALINE        GOIÂNIA  GO  LEANDRO
#
#           BANCO    RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO 16/06/2025
# 0     SANTANDER    LUARA RAYRA  QUITADO                               None
# 1  PANAMERICANO   NEWTON SOUTO  QUITADO                               None
# 2  PANAMERICANO  BRUNO MARIANO  QUITADO                               None
# 3  PANAMERICANO      ANA LIDIA  QUITADO
# 4  PANAMERICANO  GABRIEL ALVES  QUITADO                               None

# %%
query = """
SELECT *
FROM df
ORDER BY `SALDO DEVEDOR` DESC
LIMIT 10
"""

resultado = pysqldf(query)
resultado.head()  # ou .to_frame(), .to_csv(), etc.
# Out:
#          DATA CONTRATO VALOR                    NOME SALDO DEVEDOR  \
# 0  08/05/2025   225637     1         GILMAR OLKOWSKI  R$ 97.954,08
# 1  21/05/2025   211743     1    Moises Jose da Silva  R$ 97.585,44
# 2  15/05/2025   214433     1    DAULBER PILAR PIVOTO  R$ 96.282,00
# 3  06/05/2025   191136     1        JOAO MAIA JUNIOR  R$ 95.813,55
# 4  16/05/2025   233053     1  UESLEY PIRES DE AMORIM  R$ 92.429,10
#
#        DESCONTO       % PROCESSO CONSULTOR     ESCRITÓRIO  UF  DIRETOR  \
# 0  R$ 47.650,00  51,35%      SIM    SANDRA       CASCÁVEL  PR    JULIO
# 1  R$ 16.226,40  83,37%      NÃO  MICHELLE     UBERLÂNDIA  MG    JULIO
# 2  R$ 23.123,79  75,98%      NÃO    MATEUS  CAXIAS DO SUL  RS  ADRIANO
# 3  R$ 20.000,00  79,13%      NÃO   DOUGLAS       CURITIBA  PR    JULIO
# 4  R$ 24.865,76  73,10%      SIM     ALINE        GOIÂNIA  GO  LEANDRO
#
#           BANCO    RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO 16/06/2025
# 0     SANTANDER    LUARA RAYRA  QUITADO                               None
# 1  PANAMERICANO   NEWTON SOUTO  QUITADO                               None
# 2  PANAMERICANO  BRUNO MARIANO  QUITADO                               None
# 3  PANAMERICANO      ANA LIDIA  QUITADO
# 4  PANAMERICANO  GABRIEL ALVES  QUITADO                               None

# %%
query = """
SELECT *
FROM df
ORDER BY "%" DESC
LIMIT 10
"""

resultado = pysqldf(query)
resultado.head()
# Out:
#          DATA CONTRATO VALOR                          NOME SALDO DEVEDOR  \
# 0  08/05/2025   250982     1      RONILSON TAVARES DA CRUZ  R$ 28.444,52
# 1  22/05/2025   238755     1       Adair Antonio Camarotto  R$ 65.399,04
# 2  20/05/2025   200656     1    Jose Wilker de Araujo Lima  R$ 17.997,98
# 3  06/05/2025   203913     1      ANDREA PINHEIRO DE SOUZA  R$ 84.258,49
# 4  16/05/2025   200084     1  Jose Honorato da Silva Filho  R$ 66.710,20
#
#       DESCONTO       % PROCESSO CONSULTOR      ESCRITÓRIO  UF  DIRETOR  \
# 0    R$ 450,89  98,41%      SIM    MARCOS        BRASÍLIA  DF  LEANDRO
# 1  R$ 1.304,51  98,01%      NÃO   ANTONIO  MARINGA ZONA 7  PR    JULIO
# 2    R$ 467,90  97,40%      NÃO     JORGE           NATAL  RN  LEANDRO
# 3  R$ 5.298,53  93,71%      NÃO  ANGELICA          ITAJAÍ  SC  ADRIANO
# 4  R$ 5.000,00  92,50%      NÃO    MARCOS      VALPARAISO  GO  ADRIANO
#
#            BANCO      RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO 16/06/2025
# 0           ITAÚ      MARIA BRUNA  QUITADO                               None
# 1  BV FINANCEIRA  MATHEUS EDUARDO  QUITADO                               None
# 2           ITAÚ   MONYZA BENIGNO  QUITADO                               None
# 3  BV FINANCEIRA   BRUNA CRISTINA  QUITADO
# 4   PANAMERICANO   ALINE SALVADOR  QUITADO                               None

# %%
query = """
SELECT SITUAÇÃO, COUNT(*) AS TOTAL
FROM df
GROUP BY SITUAÇÃO
ORDER BY TOTAL DESC
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#   SITUAÇÃO  TOTAL
# 0  QUITADO    616

# %%
query = """
SELECT *
FROM df
WHERE "%" BETWEEN 70 AND 80
ORDER BY "%" DESC
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#          DATA CONTRATO VALOR                                   NOME  \
# 0  08/05/2025   227799     1             CLEBERSON ADRIANO DA SILVA
# 1  06/05/2025   224272     1            SIMONE AUXILIADORA DA SILVA
# 2  13/05/2025   206145     1  TAIOMARA JANICE DE OLIVEIRA CASTILHOS
# 3  26/05/2025   164607     1                Daniel da Fonseca Ribas
# 4  22/05/2025   202184     1                 Jorge Martins do Carmo
#
#   SALDO DEVEDOR      DESCONTO       % PROCESSO CONSULTOR     ESCRITÓRIO  UF  \
# 0  R$ 36.432,00   R$ 7.290,08  79,99%      SIM   MARCELO  NOVO HAMBURGO  RS
# 1  R$ 79.466,15  R$ 15.974,98  79,90%      NÃO    KARLLA       TRINDADE  GO
# 2  R$ 29.203,00   R$ 5.870,29  79,90%      NÃO  PATRICIA       SÃO JOSÉ  SC
# 3  R$ 20.122,83   R$ 4.044,43  79,90%      NÃO   MARCELO  NOVO HAMBURGO  RS
# 4  R$ 31.315,25   R$ 6.300,12  79,88%      NÃO  MICHELLE     UBERLÂNDIA  MG
#
#    DIRETOR          BANCO       RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO  \
# 0  ADRIANO  BV FINANCEIRA  ITAYNNARA DANTAS  QUITADO
# 1  ADRIANO   PANAMERICANO  GREICY GONÇALVES  QUITADO
# 2  ADRIANO  BV FINANCEIRA   JULIANA BATISTA  QUITADO
# 3  ADRIANO  BV FINANCEIRA  GREICY GONÇALVES  QUITADO
# 4    JULIO   PANAMERICANO       ANA GESSICA  QUITADO
#
#         16/06/2025
# 0             None
# 1  ADRIANO MIRANDA
# 2             None
# 3             None
# 4             None

# %%
query = """
SELECT *
FROM df
ORDER BY "DESCONTO" DESC
LIMIT 10
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#          DATA CONTRATO VALOR                           NOME SALDO DEVEDOR  \
# 0  14/05/2025   175436     1        JORGE BARBOSA SENA NETO  R$ 35.000,00
# 1  09/05/2025   207574     1    ABIGAIL ALVES LESSING VIANA  R$ 46.969,92
# 2  07/05/2025   195778     1        TATIANA PEREIRA ALMEIDA  R$ 68.753,85
# 3  21/05/2025   231036     1   Maria Lucia Nascimento Alves  R$ 48.888,00
# 4  08/05/2025   216144     1  ELIONICE SANTOS DO NASCIMENTO  R$ 44.608,00
#
#       DESCONTO       % PROCESSO CONSULTOR             ESCRITÓRIO  UF  DIRETOR  \
# 0   R$8.030,65  77,06%      NÃO    KARLLA               TRINDADE  GO  LEANDRO
# 1  R$ 9.990,00  78,73%      SIM   FABIANO          NOVO HAMBURGO  RS  ADRIANO
# 2  R$ 9.973,78  85,49%      NÃO   VANESSA              JOINVILLE  SC  ADRIANO
# 3  R$ 9.936,62  79,67%      SIM  MARILENE  FORTALEZA SÃO GERARDO  CE    JULIO
# 4  R$ 9.936,24  77,73%      NÃO  ANDERSON                VITÓRIA  ES  LEANDRO
#
#            BANCO      RESPONSÁVEL SITUAÇÃO N° DE QUITADOS DEZEMBRO 16/06/2025
# 0  BV FINANCEIRA    BRUNO MARIANO  QUITADO                               None
# 1      SANTANDER  JULIANA BATISTA  QUITADO                               None
# 2       BRADESCO   AMANDA SANTANA  QUITADO                               None
# 3  BV FINANCEIRA    GABRIEL ALVES  QUITADO                               None
# 4  BV FINANCEIRA   BRUNA CRISTINA  QUITADO                               None

# %%
query = """
SELECT CONSULTOR, COUNT(*) AS TOTAL_CONTRATOS
FROM df
GROUP BY CONSULTOR
ORDER BY TOTAL_CONTRATOS DESC
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#   CONSULTOR  TOTAL_CONTRATOS
# 0   FABIANO               25
# 1    ELLANY               25
# 2    MATEUS               19
# 3  GABRIELA               19
# 4   VANESSA               18

# %%
query = """
SELECT BANCO,
       AVG(CAST(REPLACE(REPLACE(REPLACE("%", '%', ''), ',', '.'), ' ', '') AS FLOAT)) AS MEDIA_PORCENTAGEM
FROM df
GROUP BY BANCO
ORDER BY MEDIA_PORCENTAGEM DESC
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#            BANCO  MEDIA_PORCENTAGEM
# 0           GMAC          74.765000
# 1  BV FINANCEIRA          72.662876
# 2   PANAMERICANO          72.385644
# 3        HYUNDAI          71.210000
# 4           ITAÚ          70.518966

# %%
query = """
SELECT UF, COUNT(*) AS TOTAL
FROM df
GROUP BY UF
ORDER BY TOTAL DESC
"""
resultado = pysqldf(query)
resultado.head()
# Out:
#    UF  TOTAL
# 0  SC    104
# 1  RS     97
# 2  PR     88
# 3  SP     71
# 4  GO     65
